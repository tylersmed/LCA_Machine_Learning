# %% [markdown]
# ## Initial Data Analysis
# These will be models on the dataset without processing the data first.
# Just to get an initial impression of the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
df = pd.read_csv('data_GWP_atoms.csv')
X = df.drop("GWP", axis=1)
y = df['GWP']

# split predictor and target varibles into 80% training and 20% testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
plt.boxplot(df['GWP'], vert=False)
plt.show()

# %% [markdown]
# ## Linear Regression Model

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
lin_reg_pred = lin_reg.predict(X_test)

print("Mean Squared Error:", mean_squared_error(y_test, lin_reg_pred))
print("R^2 Value:", r2_score(y_test, lin_reg_pred))

plt.scatter(y_test, lin_reg_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()
# Out:
# Mean Squared Error: 1004.821655006603
# R^2 Value: -56.98016703441408

# %% [markdown]
# ## Using an SVM

# %%
from sklearn.svm import SVR
svm = SVR()
svm.fit(X_train, y_train)
svm_pred = svm.predict(X_test)

print("Mean Squared Error:", mean_squared_error(y_test, svm_pred))
print("R^2 Value:", r2_score(y_test, svm_pred))

plt.scatter(y_test, svm_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()
# Out:
# Mean Squared Error: 19.52948411217193
# R^2 Value: -0.1268892795828762
