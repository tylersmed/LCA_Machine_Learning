# %%
#!pip install padelpy
#https://github.com/ecrl/padelpy
# Out:
# ...
#    ---------------------------------------- 20.9/20.9 MB 12.3 MB/s eta 0:00:00
# ...
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
from padelpy import from_smiles

# calculate molecular descriptors for propane
descriptors = from_smiles('C(C(=O)O)Cl')

# calculate molecular descriptors for propane and butane
descriptors = from_smiles(['C(C(=O)O)Cl', 'CCCC'])

# in addition to descriptors, calculate PubChem fingerprints
desc_fp = from_smiles('C(C(=O)O)Cl', fingerprints=True)

# only calculate fingerprints
fingerprints = from_smiles('C(C(=O)O)Cl', fingerprints=True, descriptors=False)

# setting the number of threads, this uses one cpu thread to compute descriptors
descriptors = from_smiles(['C(C(=O)O)Cl', 'CCCC'], threads = 1)

# save descriptors to a CSV file
_ = from_smiles('C(C(=O)O)Cl', output_csv='descriptors.csv')

# %%
import pandas as pd

file_path = 'data_from_paper.xlsx'

xl = pd.ExcelFile(file_path)

sheet_names = xl.sheet_names

sheet_name = 'Descriptors(1-187)-PaDEL'

data_df = xl.parse(sheet_name)
data_df
# Out:
#      Unnamed: 0  nAcid   ALogP     ALogp2      AMR       apol  naAromAtom  \
# 0             1      0 -0.6854   0.469773  16.0871  11.416344           0
# 1             2      0  0.9449   0.892836  10.8232   7.301172           0
# 2             3      0 -0.9734   0.947508  18.9987  14.509930           0
# 3             4      0 -0.6961   0.484555  20.6715  14.509930           0
# 4             5      0  0.1242   0.015426  21.5446  14.509930           0
# ..          ...    ...     ...        ...      ...        ...         ...
# 182         183      0  0.0211   0.000445  17.4128  10.884758           0
# 183         184      0 -1.1870   1.408969  16.2111  10.089551           0
# 184         185      0 -0.5281   0.278890  23.7679  14.943137           0
# 185         186      0  5.1662  26.689622  49.8066  47.827032           0
# 186         187      0 -0.1854   0.034373  14.7090  10.614344           0
#
#      nAromBond  nAtom  nHeavyAtom  ...       AMW     WTPT-1    WTPT-2  \
# ...

# %%
import pandas as pd

file_path = 'descriptors.csv'

idata_df = pd.read_csv(file_path)

idata_df
# Out:
#                                     Name  nAcid   ALogP    ALogp2      AMR  \
# 0  AUTOGEN_20240506124102306563655465475      1  0.3027  0.091627  17.3969
#
#        apol  naAromAtom  nAromBond  nAtom  nHeavyAtom  ...       P1s  \
# 0  9.304379           0          0      8           5  ...  0.535836
#
#         P2s       E1s       E2s       E3s        Ts        As        Vs  \
# 0  0.391228  0.379021  0.489006  0.195982  2.506282  1.741536  4.488529
#
#          Ks        Ds
# 0  0.390595  1.064008
#
# [1 rows x 1876 columns]

# %%
import pandas as pd

file_path = 'gwp3.xlsx'

xl = pd.ExcelFile(file_path)

sheet_names = xl.sheet_names

sheet_name = 'GWP_data'

data_dfg = xl.parse(sheet_name)
data_dfg['GWP'] = data_dfg['GWP'].str.replace(' ', '')

data_dfg['GWP'] = data_dfg['GWP'].apply(lambda x: float(x) if isinstance(x, str) else x)


data_dfg
# Out:
#         GWP
# 0     4.440
# 1     6.400
# 2     2.900
# 3     4.290
# 4     2.900
# ..      ...
# 182   2.870
# 183   9.530
# 184  15.500
# 185   0.828
# 186   4.900
#
# [187 rows x 1 columns]

# %%
nan_values = data_dfg['GWP'].isna().any()
nan_values
nan_indices = data_dfg[data_dfg['GWP'].isna()].index
nan_indices
# Out:
# Int64Index([], dtype='int64')

# %%
data_df['GWP'] = data_dfg['GWP']
data_df
# Out:
#      Unnamed: 0  nAcid   ALogP     ALogp2      AMR       apol  naAromAtom  \
# 0             1      0 -0.6854   0.469773  16.0871  11.416344           0
# 1             2      0  0.9449   0.892836  10.8232   7.301172           0
# 2             3      0 -0.9734   0.947508  18.9987  14.509930           0
# 3             4      0 -0.6961   0.484555  20.6715  14.509930           0
# 4             5      0  0.1242   0.015426  21.5446  14.509930           0
# ..          ...    ...     ...        ...      ...        ...         ...
# 182         183      0  0.0211   0.000445  17.4128  10.884758           0
# 183         184      0 -1.1870   1.408969  16.2111  10.089551           0
# 184         185      0 -0.5281   0.278890  23.7679  14.943137           0
# 185         186      0  5.1662  26.689622  49.8066  47.827032           0
# 186         187      0 -0.1854   0.034373  14.7090  10.614344           0
#
#      nAromBond  nAtom  nHeavyAtom  ...     WTPT-1    WTPT-2     WTPT-3  \
# ...

# %%
data_df = data_df.drop('Unnamed: 0', axis=1)
data_df
# Out:
#      nAcid   ALogP     ALogp2      AMR       apol  naAromAtom  nAromBond  \
# 0        0 -0.6854   0.469773  16.0871  11.416344           0          0
# 1        0  0.9449   0.892836  10.8232   7.301172           0          0
# 2        0 -0.9734   0.947508  18.9987  14.509930           0          0
# 3        0 -0.6961   0.484555  20.6715  14.509930           0          0
# 4        0  0.1242   0.015426  21.5446  14.509930           0          0
# ..     ...     ...        ...      ...        ...         ...        ...
# 182      0  0.0211   0.000445  17.4128  10.884758           0          0
# 183      0 -1.1870   1.408969  16.2111  10.089551           0          0
# 184      0 -0.5281   0.278890  23.7679  14.943137           0          0
# 185      0  5.1662  26.689622  49.8066  47.827032           0          0
# 186      0 -0.1854   0.034373  14.7090  10.614344           0          0
#
#      nAtom  nHeavyAtom  nH  ...     WTPT-1    WTPT-2     WTPT-3    WTPT-4  \
# ...

# %%
data_df.to_csv('data_GWP_atoms.csv', sep=',', index=False)

# %%
data_df
# Out:
#      nAcid   ALogP     ALogp2      AMR       apol  naAromAtom  nAromBond  \
# 0        0 -0.6854   0.469773  16.0871  11.416344           0          0
# 1        0  0.9449   0.892836  10.8232   7.301172           0          0
# 2        0 -0.9734   0.947508  18.9987  14.509930           0          0
# 3        0 -0.6961   0.484555  20.6715  14.509930           0          0
# 4        0  0.1242   0.015426  21.5446  14.509930           0          0
# ..     ...     ...        ...      ...        ...         ...        ...
# 182      0  0.0211   0.000445  17.4128  10.884758           0          0
# 183      0 -1.1870   1.408969  16.2111  10.089551           0          0
# 184      0 -0.5281   0.278890  23.7679  14.943137           0          0
# 185      0  5.1662  26.689622  49.8066  47.827032           0          0
# 186      0 -0.1854   0.034373  14.7090  10.614344           0          0
#
#      nAtom  nHeavyAtom  nH  ...     WTPT-1    WTPT-2     WTPT-3    WTPT-4  \
# ...
